# %%
import torch
import torch.nn as nn
import torch.nn.functional as f
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import torch
import torchvision
import torchvision.transforms as transforms
import sys
import numpy as np
import torch.nn as nn

# %%
print(sys.version)
print(torch.cuda.get_device_name(0))
# Out:
# 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)]
# GeForce GTX 1660

# %%
def data_loader(batch_size):
    transform = transforms.Compose(
        [transforms.ToTensor(),
         transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])  # Normalize(平均, 偏差)

    trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                            download=True, transform=transform)
    trainloader = torch.utils.data.DataLoader(trainset, batch_size,
                                              shuffle=True, num_workers=2)

    testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                           download=True, transform=transform)
    testloader = torch.utils.data.DataLoader(testset, batch_size,
                                             shuffle=False, num_workers=2)
    return trainloader, testloader

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# %matplotlib inline

# %%
trainloader, testloader = data_loader(10)
def imshow(img):
    img = img / 2 + 0.5     
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# 画像の表示
print(type(trainloader))
for i, (images, label) in enumerate(testloader):
    imshow(torchvision.utils.make_grid(images))
    if i == 10:
        break
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# <class 'torch.utils.data.dataloader.DataLoader'>

# %%
class myCNN(nn.Module):
    def __init__(self):
        super(myCNN, self).__init__()
        self.conv1 = nn.Conv2d()
    
    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# %%
history = {
    'train_loss':[],
    'test_loss':[],
    'test_acc':[]
}

device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = myCNN().to(device)

# %%
batch_size = 2000
num_epoch = 100

# %%
trainloader, testloader = data_loader(batch_size)
optimizer = torch.optim.Adam(params=net.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
for i_epoch in range(num_epoch):
    loss = None
    net.train(True)
    
    for i, (data, target) in enumerate(trainloader):
        data = data.to(device)
        target = target.to(device)
        optimizer.zero_grad()
        output = net(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        
        if i % 10 == 0:
                print('Training log: {} epoch ({} / 60000 train. data). Loss: {}'.format(i_epoch+1, (i+1)*batch_size, loss.item()))
    
    history['train_loss'].append(loss)
    
    net.eval()
    test_loss = 0
    correct = 0
    
    with torch.no_grad():
        for data, target in testloader:
            data = data.to(device)
            target = target.to(device)
            
            output = net(data)
            test_loss += f.nll_loss(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
    
    test_loss /= 10000
    print('Test loss (avg): {}, Accuracy: {}'.format(test_loss, correct / 10000))
    
    history['test_loss'].append(test_loss)
    history['test_acc'].append(correct / 10000)
# Out:
# Training log: 1 epoch (2000 / 60000 train. data). Loss: 2.3028197288513184
# Training log: 1 epoch (22000 / 60000 train. data). Loss: 2.1680564880371094
# Training log: 1 epoch (42000 / 60000 train. data). Loss: 2.1234960556030273
# Test loss (avg): -0.3563431640625, Accuracy: 0.3661
# Training log: 2 epoch (2000 / 60000 train. data). Loss: 2.0841073989868164
# Training log: 2 epoch (22000 / 60000 train. data). Loss: 2.050243616104126
# Training log: 2 epoch (42000 / 60000 train. data). Loss: 2.0376038551330566
# Test loss (avg): -0.40755081787109376, Accuracy: 0.417
# Training log: 3 epoch (2000 / 60000 train. data). Loss: 2.033750534057617
# Training log: 3 epoch (22000 / 60000 train. data). Loss: 2.0186023712158203
# Training log: 3 epoch (42000 / 60000 train. data). Loss: 1.9996790885925293
# Test loss (avg): -0.44960463256835936, Accuracy: 0.4613
# Training log: 4 epoch (2000 / 60000 train. data). Loss: 1.9722015857696533
# Training log: 4 epoch (22000 / 60000 train. data). Loss: 1.9895979166030884
# Training log: 4 epoch (42000 / 60000 train. data). Loss: 1.9737346172332764
# Test loss (avg): -0.4760340087890625, Accuracy: 0.4884
# Training log: 5 epoch (2000 / 60000 train. data). Loss: 1.9546269178390503
# Training log: 5 epoch (22000 / 60000 train. data). Loss: 1.9509164094924927
# Training log: 5 epoch (42000 / 60000 train. data). Loss: 1.9340711832046509
# Test loss (avg): -0.4854560485839844, Accuracy: 0.4985
# Training log: 6 epoch (2000 / 60000 train. data). Loss: 1.9542157649993896
# Training log: 6 epoch (22000 / 60000 train. data). Loss: 1.9003061056137085
# Training log: 6 epoch (42000 / 60000 train. data). Loss: 1.9197108745574951
# Test loss (avg): -0.5118678833007813, Accuracy: 0.5243
# Training log: 7 epoch (2000 / 60000 train. data). Loss: 1.9019211530685425
# Training log: 7 epoch (22000 / 60000 train. data). Loss: 1.8946504592895508
# Training log: 7 epoch (42000 / 60000 train. data). Loss: 1.9300440549850464
# Test loss (avg): -0.5140542663574219, Accuracy: 0.5271
# Training log: 8 epoch (2000 / 60000 train. data). Loss: 1.9038267135620117
# Training log: 8 epoch (22000 / 60000 train. data). Loss: 1.870466947555542
# Training log: 8 epoch (42000 / 60000 train. data). Loss: 1.8802564144134521
# Test loss (avg): -0.5306088745117188, Accuracy: 0.5426
# Training log: 9 epoch (2000 / 60000 train. data). Loss: 1.8770557641983032
# Training log: 9 epoch (22000 / 60000 train. data). Loss: 1.8766038417816162
# Training log: 9 epoch (42000 / 60000 train. data). Loss: 1.8522627353668213
# Test loss (avg): -0.5449819580078125, Accuracy: 0.5592
# Training log: 10 epoch (2000 / 60000 train. data). Loss: 1.8620545864105225
# Training log: 10 epoch (22000 / 60000 train. data). Loss: 1.835945725440979
# Training log: 10 epoch (42000 / 60000 train. data). Loss: 1.867071509361267
# Test loss (avg): -0.546214111328125, Accuracy: 0.5579
# Training log: 11 epoch (2000 / 60000 train. data). Loss: 1.8513295650482178
# Training log: 11 epoch (22000 / 60000 train. data). Loss: 1.8236653804779053
# Training log: 11 epoch (42000 / 60000 train. data). Loss: 1.8299064636230469
# Test loss (avg): -0.5480701904296875, Accuracy: 0.5589
# Training log: 12 epoch (2000 / 60000 train. data). Loss: 1.849470615386963
# Training log: 12 epoch (22000 / 60000 train. data). Loss: 1.817581295967102
# Training log: 12 epoch (42000 / 60000 train. data). Loss: 1.8299353122711182
# Test loss (avg): -0.5546316040039062, Accuracy: 0.5647
# Training log: 13 epoch (2000 / 60000 train. data). Loss: 1.809327244758606
# Training log: 13 epoch (22000 / 60000 train. data). Loss: 1.8141168355941772
# Training log: 13 epoch (42000 / 60000 train. data). Loss: 1.8177943229675293
# Test loss (avg): -0.5658207641601563, Accuracy: 0.5758
# Training log: 14 epoch (2000 / 60000 train. data). Loss: 1.7905793190002441
# Training log: 14 epoch (22000 / 60000 train. data). Loss: 1.8135112524032593
# Training log: 14 epoch (42000 / 60000 train. data). Loss: 1.8055144548416138
# Test loss (avg): -0.5661657592773438, Accuracy: 0.5753
# Training log: 15 epoch (2000 / 60000 train. data). Loss: 1.7938833236694336
# Training log: 15 epoch (22000 / 60000 train. data). Loss: 1.7846893072128296
# Training log: 15 epoch (42000 / 60000 train. data). Loss: 1.7931004762649536
# Test loss (avg): -0.5684888793945313, Accuracy: 0.5794
# Training log: 16 epoch (2000 / 60000 train. data). Loss: 1.7983057498931885
# Training log: 16 epoch (22000 / 60000 train. data). Loss: 1.7642756700515747
# Training log: 16 epoch (42000 / 60000 train. data). Loss: 1.7850416898727417
# Test loss (avg): -0.569864990234375, Accuracy: 0.5798
# Training log: 17 epoch (2000 / 60000 train. data). Loss: 1.7679318189620972
# Training log: 17 epoch (22000 / 60000 train. data). Loss: 1.7581965923309326
# Training log: 17 epoch (42000 / 60000 train. data). Loss: 1.752647876739502
# Test loss (avg): -0.6044925903320313, Accuracy: 0.6184
# Training log: 18 epoch (2000 / 60000 train. data). Loss: 1.7309982776641846
# Training log: 18 epoch (22000 / 60000 train. data). Loss: 1.7276414632797241
# Training log: 18 epoch (42000 / 60000 train. data). Loss: 1.7231254577636719
# Test loss (avg): -0.6281395385742188, Accuracy: 0.6392
# Training log: 19 epoch (2000 / 60000 train. data). Loss: 1.6925978660583496
# Training log: 19 epoch (22000 / 60000 train. data). Loss: 1.699074387550354
# Training log: 19 epoch (42000 / 60000 train. data). Loss: 1.6946771144866943
# Test loss (avg): -0.6360113037109375, Accuracy: 0.6473
# Training log: 20 epoch (2000 / 60000 train. data). Loss: 1.6767219305038452
# Training log: 20 epoch (22000 / 60000 train. data). Loss: 1.6749742031097412
# Training log: 20 epoch (42000 / 60000 train. data). Loss: 1.6620872020721436
# Test loss (avg): -0.6511619140625, Accuracy: 0.6651
# Training log: 21 epoch (2000 / 60000 train. data). Loss: 1.6528595685958862
# Training log: 21 epoch (22000 / 60000 train. data). Loss: 1.6476274728775024
# Training log: 21 epoch (42000 / 60000 train. data). Loss: 1.643792748451233
# Test loss (avg): -0.6509187866210937, Accuracy: 0.6648
# Training log: 22 epoch (2000 / 60000 train. data). Loss: 1.630717396736145
# Training log: 22 epoch (22000 / 60000 train. data). Loss: 1.6276061534881592
# Training log: 22 epoch (42000 / 60000 train. data). Loss: 1.6275634765625
# Test loss (avg): -0.6568557983398438, Accuracy: 0.6687
# Training log: 23 epoch (2000 / 60000 train. data). Loss: 1.6129112243652344
# Training log: 23 epoch (22000 / 60000 train. data). Loss: 1.6212210655212402
# Training log: 23 epoch (42000 / 60000 train. data). Loss: 1.6282953023910522
# Test loss (avg): -0.664422705078125, Accuracy: 0.6762
# Training log: 24 epoch (2000 / 60000 train. data). Loss: 1.5972341299057007
# Training log: 24 epoch (22000 / 60000 train. data). Loss: 1.5960750579833984
# Training log: 24 epoch (42000 / 60000 train. data). Loss: 1.5989861488342285
# Test loss (avg): -0.6641918701171875, Accuracy: 0.6747
# Training log: 25 epoch (2000 / 60000 train. data). Loss: 1.586470365524292
# Training log: 25 epoch (22000 / 60000 train. data). Loss: 1.589329481124878
# Training log: 25 epoch (42000 / 60000 train. data). Loss: 1.5788078308105469
# Test loss (avg): -0.6713028930664062, Accuracy: 0.6843
# Training log: 26 epoch (2000 / 60000 train. data). Loss: 1.588274359703064
# Training log: 26 epoch (22000 / 60000 train. data). Loss: 1.5638482570648193
# Training log: 26 epoch (42000 / 60000 train. data). Loss: 1.5802754163742065
# Test loss (avg): -0.6710279541015625, Accuracy: 0.6826
# Training log: 27 epoch (2000 / 60000 train. data). Loss: 1.5767349004745483
# Training log: 27 epoch (22000 / 60000 train. data). Loss: 1.5660966634750366
# Training log: 27 epoch (42000 / 60000 train. data). Loss: 1.5622423887252808
# Test loss (avg): -0.6670442504882812, Accuracy: 0.6775
# Training log: 28 epoch (2000 / 60000 train. data). Loss: 1.5666965246200562
# Training log: 28 epoch (22000 / 60000 train. data). Loss: 1.5806316137313843
# Training log: 28 epoch (42000 / 60000 train. data). Loss: 1.5469036102294922
# Test loss (avg): -0.6722451782226563, Accuracy: 0.684
# Training log: 29 epoch (2000 / 60000 train. data). Loss: 1.5756486654281616
# Training log: 29 epoch (22000 / 60000 train. data). Loss: 1.5558735132217407
# Training log: 29 epoch (42000 / 60000 train. data). Loss: 1.5554063320159912
# Test loss (avg): -0.6728201782226563, Accuracy: 0.684
# Training log: 30 epoch (2000 / 60000 train. data). Loss: 1.559154987335205
# Training log: 30 epoch (22000 / 60000 train. data). Loss: 1.5436195135116577
# Training log: 30 epoch (42000 / 60000 train. data). Loss: 1.5507779121398926
# Test loss (avg): -0.6759465209960938, Accuracy: 0.6858
# Training log: 31 epoch (2000 / 60000 train. data). Loss: 1.5480999946594238
# Training log: 31 epoch (22000 / 60000 train. data). Loss: 1.5361762046813965
# Training log: 31 epoch (42000 / 60000 train. data). Loss: 1.553788661956787
# Test loss (avg): -0.6765564086914062, Accuracy: 0.6861
# Training log: 32 epoch (2000 / 60000 train. data). Loss: 1.553104281425476
# Training log: 32 epoch (22000 / 60000 train. data). Loss: 1.5578018426895142
# Training log: 32 epoch (42000 / 60000 train. data). Loss: 1.556472659111023
# Test loss (avg): -0.6784740234375, Accuracy: 0.6867
# Training log: 33 epoch (2000 / 60000 train. data). Loss: 1.5435340404510498
# Training log: 33 epoch (22000 / 60000 train. data). Loss: 1.5314208269119263
# Training log: 33 epoch (42000 / 60000 train. data). Loss: 1.5487946271896362
# Test loss (avg): -0.6784448364257812, Accuracy: 0.6891
# Training log: 34 epoch (2000 / 60000 train. data). Loss: 1.5325913429260254
# Training log: 34 epoch (22000 / 60000 train. data). Loss: 1.5451335906982422
# Training log: 34 epoch (42000 / 60000 train. data). Loss: 1.5375003814697266
# Test loss (avg): -0.676014501953125, Accuracy: 0.6864
# Training log: 35 epoch (2000 / 60000 train. data). Loss: 1.5494025945663452
# Training log: 35 epoch (22000 / 60000 train. data). Loss: 1.5407220125198364
# Training log: 35 epoch (42000 / 60000 train. data). Loss: 1.538110613822937
# Test loss (avg): -0.6769456787109375, Accuracy: 0.6865
# Training log: 36 epoch (2000 / 60000 train. data). Loss: 1.5326341390609741
# Training log: 36 epoch (22000 / 60000 train. data). Loss: 1.5330610275268555
# Training log: 36 epoch (42000 / 60000 train. data). Loss: 1.539040446281433
# Test loss (avg): -0.6799911254882812, Accuracy: 0.6896
# Training log: 37 epoch (2000 / 60000 train. data). Loss: 1.5412040948867798
# Training log: 37 epoch (22000 / 60000 train. data). Loss: 1.5310002565383911
# Training log: 37 epoch (42000 / 60000 train. data). Loss: 1.5316702127456665
# Test loss (avg): -0.6794802124023438, Accuracy: 0.6881
# Training log: 38 epoch (2000 / 60000 train. data). Loss: 1.53974449634552
# Training log: 38 epoch (22000 / 60000 train. data). Loss: 1.5356944799423218
# Training log: 38 epoch (42000 / 60000 train. data). Loss: 1.5340803861618042
# Test loss (avg): -0.6795894287109375, Accuracy: 0.6874
# Training log: 39 epoch (2000 / 60000 train. data). Loss: 1.5402472019195557
# Training log: 39 epoch (22000 / 60000 train. data). Loss: 1.5365420579910278
# Training log: 39 epoch (42000 / 60000 train. data). Loss: 1.5378085374832153
# Test loss (avg): -0.67753837890625, Accuracy: 0.6869
# Training log: 40 epoch (2000 / 60000 train. data). Loss: 1.5309717655181885
# Training log: 40 epoch (22000 / 60000 train. data). Loss: 1.5300308465957642
# Training log: 40 epoch (42000 / 60000 train. data). Loss: 1.5350273847579956
# Test loss (avg): -0.68034013671875, Accuracy: 0.6908
# Training log: 41 epoch (2000 / 60000 train. data). Loss: 1.5360171794891357
# Training log: 41 epoch (22000 / 60000 train. data). Loss: 1.5257097482681274
# Training log: 41 epoch (42000 / 60000 train. data). Loss: 1.5380059480667114
# Test loss (avg): -0.679977294921875, Accuracy: 0.6895
# Training log: 42 epoch (2000 / 60000 train. data). Loss: 1.5329158306121826
# Training log: 42 epoch (22000 / 60000 train. data). Loss: 1.5266096591949463
# Training log: 42 epoch (42000 / 60000 train. data). Loss: 1.5342133045196533
# Test loss (avg): -0.6788684814453125, Accuracy: 0.6869
# Training log: 43 epoch (2000 / 60000 train. data). Loss: 1.5208994150161743
# Training log: 43 epoch (22000 / 60000 train. data). Loss: 1.5297759771347046
# Training log: 43 epoch (42000 / 60000 train. data). Loss: 1.537477970123291
# Test loss (avg): -0.6808667724609375, Accuracy: 0.6899
# Training log: 44 epoch (2000 / 60000 train. data). Loss: 1.525352954864502
# Training log: 44 epoch (22000 / 60000 train. data). Loss: 1.5421901941299438
# Training log: 44 epoch (42000 / 60000 train. data). Loss: 1.5263203382492065
# Test loss (avg): -0.6807005126953125, Accuracy: 0.6881
# Training log: 45 epoch (2000 / 60000 train. data). Loss: 1.5220670700073242
# Training log: 45 epoch (22000 / 60000 train. data). Loss: 1.5150805711746216
# Training log: 45 epoch (42000 / 60000 train. data). Loss: 1.5303881168365479
# Test loss (avg): -0.6821022827148437, Accuracy: 0.6889
# Training log: 46 epoch (2000 / 60000 train. data). Loss: 1.53608238697052
# Training log: 46 epoch (22000 / 60000 train. data). Loss: 1.5233622789382935
# Training log: 46 epoch (42000 / 60000 train. data). Loss: 1.5255109071731567
# Test loss (avg): -0.6786883666992187, Accuracy: 0.684
# Training log: 47 epoch (2000 / 60000 train. data). Loss: 1.526657223701477
# Training log: 47 epoch (22000 / 60000 train. data). Loss: 1.5263968706130981
# Training log: 47 epoch (42000 / 60000 train. data). Loss: 1.526302456855774
# Test loss (avg): -0.6792310424804687, Accuracy: 0.6867
# Training log: 48 epoch (2000 / 60000 train. data). Loss: 1.518412709236145
# Training log: 48 epoch (22000 / 60000 train. data). Loss: 1.5271499156951904
# Training log: 48 epoch (42000 / 60000 train. data). Loss: 1.5322470664978027
# Test loss (avg): -0.68114208984375, Accuracy: 0.6874
# Training log: 49 epoch (2000 / 60000 train. data). Loss: 1.512192726135254
# Training log: 49 epoch (22000 / 60000 train. data). Loss: 1.5244364738464355
# Training log: 49 epoch (42000 / 60000 train. data). Loss: 1.5187643766403198
# Test loss (avg): -0.6811573120117187, Accuracy: 0.6876
# Training log: 50 epoch (2000 / 60000 train. data). Loss: 1.5267045497894287
# Training log: 50 epoch (22000 / 60000 train. data). Loss: 1.515860676765442
# Training log: 50 epoch (42000 / 60000 train. data). Loss: 1.52359938621521
# Test loss (avg): -0.6807928344726563, Accuracy: 0.6904
# Training log: 51 epoch (2000 / 60000 train. data). Loss: 1.5123578310012817
# Training log: 51 epoch (22000 / 60000 train. data). Loss: 1.5289020538330078
# Training log: 51 epoch (42000 / 60000 train. data). Loss: 1.5252715349197388
# Test loss (avg): -0.6793563354492187, Accuracy: 0.6858
# Training log: 52 epoch (2000 / 60000 train. data). Loss: 1.5304769277572632
# Training log: 52 epoch (22000 / 60000 train. data). Loss: 1.5181771516799927
# Training log: 52 epoch (42000 / 60000 train. data). Loss: 1.5280009508132935
# Test loss (avg): -0.6791728637695312, Accuracy: 0.6874
# Training log: 53 epoch (2000 / 60000 train. data). Loss: 1.5265194177627563
# Training log: 53 epoch (22000 / 60000 train. data). Loss: 1.522700548171997
# Training log: 53 epoch (42000 / 60000 train. data). Loss: 1.5266214609146118
# Test loss (avg): -0.681113037109375, Accuracy: 0.6883
# Training log: 54 epoch (2000 / 60000 train. data). Loss: 1.5264414548873901
# Training log: 54 epoch (22000 / 60000 train. data). Loss: 1.5198028087615967
# Training log: 54 epoch (42000 / 60000 train. data). Loss: 1.5293759107589722
# Test loss (avg): -0.6814850708007812, Accuracy: 0.6877
# Training log: 55 epoch (2000 / 60000 train. data). Loss: 1.525804877281189
# Training log: 55 epoch (22000 / 60000 train. data). Loss: 1.5320048332214355
# Training log: 55 epoch (42000 / 60000 train. data). Loss: 1.5230618715286255
# Test loss (avg): -0.6804473754882813, Accuracy: 0.689
# Training log: 56 epoch (2000 / 60000 train. data). Loss: 1.5320236682891846
# Training log: 56 epoch (22000 / 60000 train. data). Loss: 1.523953914642334
# Training log: 56 epoch (42000 / 60000 train. data). Loss: 1.518518090248108
# Test loss (avg): -0.6836266357421875, Accuracy: 0.6933
# Training log: 57 epoch (2000 / 60000 train. data). Loss: 1.5179028511047363
# Training log: 57 epoch (22000 / 60000 train. data). Loss: 1.5181032419204712
# Training log: 57 epoch (42000 / 60000 train. data). Loss: 1.526935338973999
# Test loss (avg): -0.6823906372070313, Accuracy: 0.6893
# Training log: 58 epoch (2000 / 60000 train. data). Loss: 1.5263947248458862
# Training log: 58 epoch (22000 / 60000 train. data). Loss: 1.5222784280776978
# Training log: 58 epoch (42000 / 60000 train. data). Loss: 1.5237246751785278
# Test loss (avg): -0.6810796630859375, Accuracy: 0.689
# Training log: 59 epoch (2000 / 60000 train. data). Loss: 1.5250632762908936
# Training log: 59 epoch (22000 / 60000 train. data). Loss: 1.5223687887191772
# Training log: 59 epoch (42000 / 60000 train. data). Loss: 1.5160971879959106
# Test loss (avg): -0.6838758666992187, Accuracy: 0.6935
# Training log: 60 epoch (2000 / 60000 train. data). Loss: 1.5303560495376587
# Training log: 60 epoch (22000 / 60000 train. data). Loss: 1.520437479019165
# Training log: 60 epoch (42000 / 60000 train. data). Loss: 1.5117160081863403
# Test loss (avg): -0.6811211303710938, Accuracy: 0.688
# Training log: 61 epoch (2000 / 60000 train. data). Loss: 1.5261931419372559
# Training log: 61 epoch (22000 / 60000 train. data). Loss: 1.5174965858459473
# Training log: 61 epoch (42000 / 60000 train. data). Loss: 1.5268315076828003
# Test loss (avg): -0.6837065795898437, Accuracy: 0.6912
# Training log: 62 epoch (2000 / 60000 train. data). Loss: 1.5267295837402344
# Training log: 62 epoch (22000 / 60000 train. data). Loss: 1.5131545066833496
# Training log: 62 epoch (42000 / 60000 train. data). Loss: 1.5201057195663452
# Test loss (avg): -0.6830930786132813, Accuracy: 0.6913
# Training log: 63 epoch (2000 / 60000 train. data). Loss: 1.5293174982070923
# Training log: 63 epoch (22000 / 60000 train. data). Loss: 1.5184746980667114
# Training log: 63 epoch (42000 / 60000 train. data). Loss: 1.5157835483551025
# Test loss (avg): -0.6794865478515625, Accuracy: 0.6831
# Training log: 64 epoch (2000 / 60000 train. data). Loss: 1.5284897089004517
# Training log: 64 epoch (22000 / 60000 train. data). Loss: 1.5125588178634644
# Training log: 64 epoch (42000 / 60000 train. data). Loss: 1.5338588953018188
# Test loss (avg): -0.6829485961914062, Accuracy: 0.6893
# Training log: 65 epoch (2000 / 60000 train. data). Loss: 1.5211422443389893
# Training log: 65 epoch (22000 / 60000 train. data). Loss: 1.5221580266952515
# Training log: 65 epoch (42000 / 60000 train. data). Loss: 1.525945782661438
# Test loss (avg): -0.6824850341796875, Accuracy: 0.6902
# Training log: 66 epoch (2000 / 60000 train. data). Loss: 1.5114859342575073
# Training log: 66 epoch (22000 / 60000 train. data). Loss: 1.5193415880203247
# Training log: 66 epoch (42000 / 60000 train. data). Loss: 1.5238627195358276
# Test loss (avg): -0.683601416015625, Accuracy: 0.691
# Training log: 67 epoch (2000 / 60000 train. data). Loss: 1.5067505836486816
# Training log: 67 epoch (22000 / 60000 train. data). Loss: 1.5187628269195557
# Training log: 67 epoch (42000 / 60000 train. data). Loss: 1.522021770477295
# Test loss (avg): -0.68402607421875, Accuracy: 0.6899
# Training log: 68 epoch (2000 / 60000 train. data). Loss: 1.512439489364624
# Training log: 68 epoch (22000 / 60000 train. data). Loss: 1.5215613842010498
# Training log: 68 epoch (42000 / 60000 train. data). Loss: 1.5146359205245972
# Test loss (avg): -0.6829517822265625, Accuracy: 0.6895
# Training log: 69 epoch (2000 / 60000 train. data). Loss: 1.5169419050216675
# Training log: 69 epoch (22000 / 60000 train. data). Loss: 1.5204041004180908
# Training log: 69 epoch (42000 / 60000 train. data). Loss: 1.51401948928833
# Test loss (avg): -0.6842868041992187, Accuracy: 0.6923
# Training log: 70 epoch (2000 / 60000 train. data). Loss: 1.520113229751587
# Training log: 70 epoch (22000 / 60000 train. data). Loss: 1.5180233716964722
# Training log: 70 epoch (42000 / 60000 train. data). Loss: 1.5197439193725586
# Test loss (avg): -0.6858806396484375, Accuracy: 0.6933
# Training log: 71 epoch (2000 / 60000 train. data). Loss: 1.5208157300949097
# Training log: 71 epoch (22000 / 60000 train. data). Loss: 1.516299843788147
# Training log: 71 epoch (42000 / 60000 train. data). Loss: 1.5162513256072998
# Test loss (avg): -0.685804541015625, Accuracy: 0.693
# Training log: 72 epoch (2000 / 60000 train. data). Loss: 1.5195415019989014
# Training log: 72 epoch (22000 / 60000 train. data). Loss: 1.521763563156128
# Training log: 72 epoch (42000 / 60000 train. data). Loss: 1.5173521041870117
# Test loss (avg): -0.6858164184570312, Accuracy: 0.6917
# Training log: 73 epoch (2000 / 60000 train. data). Loss: 1.5240038633346558
# Training log: 73 epoch (22000 / 60000 train. data). Loss: 1.5214277505874634
# Training log: 73 epoch (42000 / 60000 train. data). Loss: 1.5168981552124023
# Test loss (avg): -0.6842449340820312, Accuracy: 0.6908
# Training log: 74 epoch (2000 / 60000 train. data). Loss: 1.5263960361480713
# Training log: 74 epoch (22000 / 60000 train. data). Loss: 1.5237971544265747
# Training log: 74 epoch (42000 / 60000 train. data). Loss: 1.5247622728347778
# Test loss (avg): -0.6838755004882813, Accuracy: 0.6908
# Training log: 75 epoch (2000 / 60000 train. data). Loss: 1.5149836540222168
# Training log: 75 epoch (22000 / 60000 train. data). Loss: 1.5114331245422363
# Training log: 75 epoch (42000 / 60000 train. data). Loss: 1.5096311569213867
# Test loss (avg): -0.6841826293945312, Accuracy: 0.6899
# Training log: 76 epoch (2000 / 60000 train. data). Loss: 1.5135308504104614
# Training log: 76 epoch (22000 / 60000 train. data). Loss: 1.512406826019287
# Training log: 76 epoch (42000 / 60000 train. data). Loss: 1.518836259841919
# Test loss (avg): -0.6851383666992188, Accuracy: 0.6915
# Training log: 77 epoch (2000 / 60000 train. data). Loss: 1.5081498622894287
# Training log: 77 epoch (22000 / 60000 train. data). Loss: 1.5139350891113281
# Training log: 77 epoch (42000 / 60000 train. data). Loss: 1.5111958980560303
# Test loss (avg): -0.6828847534179687, Accuracy: 0.6882
# Training log: 78 epoch (2000 / 60000 train. data). Loss: 1.5209681987762451
# Training log: 78 epoch (22000 / 60000 train. data). Loss: 1.5166077613830566
# Training log: 78 epoch (42000 / 60000 train. data). Loss: 1.5106136798858643
# Test loss (avg): -0.6808316772460937, Accuracy: 0.687
# Training log: 79 epoch (2000 / 60000 train. data). Loss: 1.5215678215026855
# Training log: 79 epoch (22000 / 60000 train. data). Loss: 1.521929144859314
# Training log: 79 epoch (42000 / 60000 train. data). Loss: 1.5194026231765747
# Test loss (avg): -0.6839209594726563, Accuracy: 0.688
# Training log: 80 epoch (2000 / 60000 train. data). Loss: 1.5101985931396484
# Training log: 80 epoch (22000 / 60000 train. data). Loss: 1.5189380645751953
# Training log: 80 epoch (42000 / 60000 train. data). Loss: 1.51531982421875
# Test loss (avg): -0.6845386108398438, Accuracy: 0.6892
# Training log: 81 epoch (2000 / 60000 train. data). Loss: 1.5104414224624634
# Training log: 81 epoch (22000 / 60000 train. data). Loss: 1.5170661211013794
# Training log: 81 epoch (42000 / 60000 train. data). Loss: 1.5223356485366821
# Test loss (avg): -0.6844577880859375, Accuracy: 0.6909
# Training log: 82 epoch (2000 / 60000 train. data). Loss: 1.5198190212249756
# Training log: 82 epoch (22000 / 60000 train. data). Loss: 1.5121572017669678
# Training log: 82 epoch (42000 / 60000 train. data). Loss: 1.5045828819274902
# Test loss (avg): -0.680100244140625, Accuracy: 0.6857
# Training log: 83 epoch (2000 / 60000 train. data). Loss: 1.5216546058654785
# Training log: 83 epoch (22000 / 60000 train. data). Loss: 1.5146853923797607
# Training log: 83 epoch (42000 / 60000 train. data). Loss: 1.5083515644073486
# Test loss (avg): -0.6810832397460937, Accuracy: 0.6842
# Training log: 84 epoch (2000 / 60000 train. data). Loss: 1.5096262693405151
# Training log: 84 epoch (22000 / 60000 train. data). Loss: 1.5149495601654053
# Training log: 84 epoch (42000 / 60000 train. data). Loss: 1.5175635814666748
# Test loss (avg): -0.525968115234375, Accuracy: 0.5291
# Training log: 85 epoch (2000 / 60000 train. data). Loss: 1.8258532285690308
# Training log: 85 epoch (22000 / 60000 train. data). Loss: 2.143785238265991
# Training log: 85 epoch (42000 / 60000 train. data). Loss: 2.2004165649414062
# Test loss (avg): -0.29776403198242185, Accuracy: 0.2975
# Training log: 86 epoch (2000 / 60000 train. data). Loss: 2.1603806018829346
# Training log: 86 epoch (22000 / 60000 train. data). Loss: 2.1272854804992676
# Training log: 86 epoch (42000 / 60000 train. data). Loss: 2.1339023113250732
# Test loss (avg): -0.32821617431640626, Accuracy: 0.3273
# Training log: 87 epoch (2000 / 60000 train. data). Loss: 2.1406478881835938
# Training log: 87 epoch (22000 / 60000 train. data). Loss: 2.0965166091918945
# Training log: 87 epoch (42000 / 60000 train. data). Loss: 2.129678726196289
# Test loss (avg): -0.3368638427734375, Accuracy: 0.337
# Training log: 88 epoch (2000 / 60000 train. data). Loss: 2.102863311767578
# Training log: 88 epoch (22000 / 60000 train. data). Loss: 2.130092144012451
# Training log: 88 epoch (42000 / 60000 train. data). Loss: 2.1166493892669678
# Test loss (avg): -0.3371900268554687, Accuracy: 0.3377
# Training log: 89 epoch (2000 / 60000 train. data). Loss: 2.0888564586639404
# Training log: 89 epoch (22000 / 60000 train. data). Loss: 2.0968239307403564
# Training log: 89 epoch (42000 / 60000 train. data). Loss: 2.097592830657959
# Test loss (avg): -0.34108287353515626, Accuracy: 0.341
# Training log: 90 epoch (2000 / 60000 train. data). Loss: 2.098151206970215
# Training log: 90 epoch (22000 / 60000 train. data). Loss: 2.0781772136688232
# Training log: 90 epoch (42000 / 60000 train. data). Loss: 2.0753519535064697
# Test loss (avg): -0.34468717651367187, Accuracy: 0.3448
# Training log: 91 epoch (2000 / 60000 train. data). Loss: 2.1011128425598145
# Training log: 91 epoch (22000 / 60000 train. data). Loss: 2.091050386428833
# Training log: 91 epoch (42000 / 60000 train. data). Loss: 2.0861966609954834
# Test loss (avg): -0.3407822204589844, Accuracy: 0.342
# Training log: 92 epoch (2000 / 60000 train. data). Loss: 2.0958845615386963
# Training log: 92 epoch (22000 / 60000 train. data). Loss: 2.089470386505127
# Training log: 92 epoch (42000 / 60000 train. data). Loss: 2.088618278503418
# Test loss (avg): -0.34737341918945314, Accuracy: 0.348
# Training log: 93 epoch (2000 / 60000 train. data). Loss: 2.090771198272705
# Training log: 93 epoch (22000 / 60000 train. data). Loss: 2.09647274017334
# Training log: 93 epoch (42000 / 60000 train. data). Loss: 2.091149091720581
# Test loss (avg): -0.35103270263671876, Accuracy: 0.3528
# Training log: 94 epoch (2000 / 60000 train. data). Loss: 2.0859451293945312
# Training log: 94 epoch (22000 / 60000 train. data). Loss: 2.0603418350219727
# Training log: 94 epoch (42000 / 60000 train. data). Loss: 2.0842061042785645
# Test loss (avg): -0.35125020141601565, Accuracy: 0.3523
# Training log: 95 epoch (2000 / 60000 train. data). Loss: 2.0780112743377686
# Training log: 95 epoch (22000 / 60000 train. data). Loss: 2.0665218830108643
# Training log: 95 epoch (42000 / 60000 train. data). Loss: 2.0246217250823975
# Test loss (avg): -0.4040211303710938, Accuracy: 0.4048
# Training log: 96 epoch (2000 / 60000 train. data). Loss: 2.0306482315063477
# Training log: 96 epoch (22000 / 60000 train. data). Loss: 2.0192294120788574
# Training log: 96 epoch (42000 / 60000 train. data). Loss: 1.9898992776870728
# Test loss (avg): -0.4162528503417969, Accuracy: 0.4174
# Training log: 97 epoch (2000 / 60000 train. data). Loss: 1.9913995265960693
# Training log: 97 epoch (22000 / 60000 train. data). Loss: 1.996590256690979
# Training log: 97 epoch (42000 / 60000 train. data). Loss: 1.9610294103622437
# Test loss (avg): -0.4235490966796875, Accuracy: 0.425
# Training log: 98 epoch (2000 / 60000 train. data). Loss: 1.9673728942871094
# Training log: 98 epoch (22000 / 60000 train. data). Loss: 1.9762866497039795
# Training log: 98 epoch (42000 / 60000 train. data). Loss: 1.9807417392730713
# Test loss (avg): -0.41597669067382814, Accuracy: 0.4186
# Training log: 99 epoch (2000 / 60000 train. data). Loss: 1.9708325862884521
# Training log: 99 epoch (22000 / 60000 train. data). Loss: 1.9712002277374268
# Training log: 99 epoch (42000 / 60000 train. data). Loss: 1.9587955474853516
# Test loss (avg): -0.4218088623046875, Accuracy: 0.4232
# Training log: 100 epoch (2000 / 60000 train. data). Loss: 1.9722822904586792
# Training log: 100 epoch (22000 / 60000 train. data). Loss: 1.978013277053833
# Training log: 100 epoch (42000 / 60000 train. data). Loss: 1.9629783630371094
# Test loss (avg): -0.42323092041015625, Accuracy: 0.426

# %%
print(num_epoch)
print(history)
plt.figure()
plt.plot(range(len(history['train_loss'])), history['train_loss'], label='train_loss')
plt.plot(range(len(history['test_loss'])), history['test_loss'], label='test_loss')
plt.xlabel('epoch')
plt.legend()
plt.savefig('loss.png')

plt.figure()
plt.plot(range(len(history['test_acc'])), history['test_acc'])
plt.title('test accuracy')
plt.xlabel('epoch')
plt.savefig('test_acc.png')
# Out:
# 100
# {'train_loss': [tensor(2.0907, device='cuda:0', grad_fn=<NllLossBackward>), tensor(2.0211, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.9811, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.9668, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.9168, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.9090, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.8989, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.8651, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.8666, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.8607, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.8113, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.8298, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.8255, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.8135, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.7916, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.7740, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.7543, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.7256, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.6911, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.6730, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.6418, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.6356, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.6230, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5996, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5783, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5712, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5659, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5670, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5602, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5525, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5526, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5449, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5497, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5437, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5328, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5379, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5272, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5263, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5322, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5324, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5317, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5320, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5375, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5279, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5242, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5322, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5217, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5370, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5188, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5292, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5288, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5214, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5188, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5210, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5158, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5105, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5272, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5206, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5194, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5174, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5201, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5136, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5157, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5171, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5212, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5180, device='cuda:0', grad_fn=<NllLossBackward>), tensor(1.5145, device='c ...
